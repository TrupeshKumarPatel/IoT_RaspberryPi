# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
log_file_path = "../../experiment_results/"
log_list = os.listdir(log_file_path)
log_list.remove('.DS_Store')
log_list.remove('Images')
print(log_list)
# Out:
# ['diff_place_sec_to_bus_hub_2.log', 'diff_place_sec_to_bus_hub.log', 'in_lab.log', 'in_floor.log', 'diff_floor.log', 'diff_place_sec_to_fountain.log']

# %%
## Extract results from "diff_place_sec_to_bus_hub_2.log" 
each_log_path = os.path.join(log_file_path, log_list[0])
df_bus_hub_2 = pd.DataFrame(columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                       'Send:Pack', 'Send:Lost%', 'Send:Jitter'])

f = open(each_log_path, "r")
for each_line in f:
    line_split = each_line.split()
    if (len(line_split) == 13):
        df_each_line = pd.DataFrame([[line_split[0], line_split[3], line_split[6].replace('%)',''), line_split[7],
                                      line_split[8], line_split[11].replace('%)',''), line_split[12]]], 
                                    columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                               'Send:Pack', 'Send:Lost%', 'Send:Jitter'])
        df_bus_hub_2 = pd.concat([df_bus_hub_2, df_each_line])
        
print("="*70)
print("Results at : ", log_list[0])
print("="*70)
print(df_bus_hub_2)
# Out:
# ...
# Results at :  diff_place_sec_to_bus_hub_2.log
# ...
#               Peer   Recv:Pack Recv:Lost% Recv:Jitter   Send:Pack Send:Lost%  \
# 0   10.127.204.227  0000003826       1.21      0.0000  0000003954       1.11
# 0    10.127.10.203  0000003781       0.00      0.0000  0000003707       1.54
# 0   10.127.204.227  0000003878       1.20      0.0000  0000004006       1.10
# 0    10.127.10.203  0000003834       0.00      0.0000  0000003758       1.52
# 0   10.127.204.227  0000003930       1.18      0.0000  0000004058       1.08
# ..             ...         ...        ...         ...         ...        ...
# 0    10.127.10.203  0000006787       0.10      0.0000  0000006678       1.57
# 0   10.127.204.227  0000006851       1.25      0.0000  0000006979       1.49
# 0    10.127.10.203  0000006839       0.10      0.0000  0000006729       1.58
# 0   10.127.204.227  0000006902       1.24      0.0000  0000007030       1.48
# 0    10.127.10.203  0000006891       0.10      0.0000  0000006781       1.56
# ...

# %%
## Extract results from "diff_place_sec_to_bus_hub.log" 
each_log_path = os.path.join(log_file_path, log_list[1])
df_bus_hub = pd.DataFrame(columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                     'Send:Pack', 'Send:Lost%', 'Send:Jitter'])

f = open(each_log_path, "r")
for each_line in f:
    line_split = each_line.split()
    if (len(line_split) == 13):
        df_each_line = pd.DataFrame([[line_split[0], line_split[3], line_split[6].replace('%)',''), line_split[7],
                                      line_split[8], line_split[11].replace('%)',''), line_split[12]]], 
                                    columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                               'Send:Pack', 'Send:Lost%', 'Send:Jitter'])
        df_bus_hub = pd.concat([df_bus_hub, df_each_line])
        
print("="*70)
print("Results at : ", log_list[1])
print("="*70)
print(df_bus_hub)
# Out:
# ...
# Results at :  diff_place_sec_to_bus_hub.log
# ...
#               Peer   Recv:Pack Recv:Lost% Recv:Jitter   Send:Pack Send:Lost%  \
# 0   10.127.204.227  0000000301       0.00      0.0000  0000000400       0.75
# 0    10.127.10.203  0000000211       0.00      0.0000  0000000185       0.00
# 0   10.127.204.227  0000000354       0.00      0.0000  0000000451       0.67
# 0    10.127.10.203  0000000263       0.00      0.0000  0000000236       0.00
# 0   10.127.204.227  0000000405       0.00      0.0000  0000000503       0.60
# ..             ...         ...        ...         ...         ...        ...
# 0    10.127.10.203  0000003235       0.00      0.0000  0000003160       1.77
# 0   10.127.204.227  0000003332       1.36      0.0000  0000003461       1.18
# 0    10.127.10.203  0000003287       0.00      0.0000  0000003212       1.74
# 0   10.127.204.227  0000003384       1.34      0.0000  0000003512       1.17
# 0    10.127.10.203  0000003339       0.00      0.0000  0000003264       1.72
#
# ...

# %%
## Extract results from "in_lab.log" 
each_log_path = os.path.join(log_file_path, log_list[2])
df_in_lab = pd.DataFrame(columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                    'Send:Pack', 'Send:Lost%', 'Send:Jitter'])

f = open(each_log_path, "r")
for each_line in f:
    line_split = each_line.split()
    if (len(line_split) == 13):
        df_each_line = pd.DataFrame([[line_split[0], line_split[3], line_split[6].replace('%)',''), line_split[7],
                                      line_split[8], line_split[11].replace('%)',''), line_split[12]]], 
                                    columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                               'Send:Pack', 'Send:Lost%', 'Send:Jitter'])
        df_in_lab = pd.concat([df_in_lab, df_each_line])
        
print("="*70)
print("Results at : ", log_list[2])
print("="*70)
print(df_in_lab)
# Out:
# ...
# Results at :  in_lab.log
# ...
#               Peer   Recv:Pack Recv:Lost% Recv:Jitter   Send:Pack Send:Lost%  \
# 0    10.127.10.203  0000001349       0.07      0.0000  0000001279       0.70
# 0   10.127.204.227  0000001355       0.15      0.0000  0000001429       0.77
# 0    10.127.10.203  0000001401       0.07      0.0000  0000001331       0.68
# 0   10.127.204.227  0000001407       0.14      0.0000  0000001481       0.74
# 0    10.127.10.203  0000001454       0.07      0.0000  0000001384       0.65
# ..             ...         ...        ...         ...         ...        ...
# 0   10.127.204.227  0000004398       0.05      0.0000  0000004472       0.56
# 0    10.127.10.203  0000004445       0.02      0.0000  0000004375       0.39
# 0   10.127.204.227  0000004450       0.04      0.0000  0000004525       0.55
# 0    10.127.10.203  0000004497       0.02      0.0000  0000004428       0.38
# 0   10.127.204.227  0000004503       0.04      0.0000  0000004577       0.55
#
#    Send:Jitter
# ...

# %%
## Extract results from "in_floor.log" 
each_log_path = os.path.join(log_file_path, log_list[3])
df_in_floor = pd.DataFrame(columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                      'Send:Pack', 'Send:Lost%', 'Send:Jitter'])

f = open(each_log_path, "r")
for each_line in f:
    line_split = each_line.split()
    if (len(line_split) == 13):
        df_each_line = pd.DataFrame([[line_split[0], line_split[3], line_split[6].replace('%)',''), line_split[7],
                                      line_split[8], line_split[11].replace('%)',''), line_split[12]]], 
                                    columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                               'Send:Pack', 'Send:Lost%', 'Send:Jitter'])
        df_in_floor = pd.concat([df_in_floor, df_each_line])
        
print("="*70)
print("Results at : ", log_list[3])
print("="*70)
print(df_in_floor)
# Out:
# ...
# Results at :  in_floor.log
# ...
#               Peer   Recv:Pack Recv:Lost% Recv:Jitter   Send:Pack Send:Lost%  \
# 0    10.127.10.203  0000000302       0.00      0.0000  0000000295       0.34
# 0   10.127.204.227  0000000554       0.00      0.0000  0000000659       0.30
# 0    10.127.10.203  0000000354       0.00      0.0000  0000000348       0.29
# 0   10.127.204.227  0000000607       0.00      0.0000  0000000712       0.14
# 0    10.127.10.203  0000000407       0.00      0.0000  0000000400       0.25
# ..             ...         ...        ...         ...         ...        ...
# 0   10.127.204.227  0000003587       0.33      0.0000  0000003683       0.62
# 0    10.127.10.203  0000003395       0.12      0.0000  0000003357       0.63
# 0   10.127.204.227  0000003639       0.33      0.0000  0000003735       0.62
# 0    10.127.10.203  0000003447       0.12      0.0000  0000003410       0.65
# 0   10.127.204.227  0000003692       0.32      0.0000  0000003788       0.63
#
#    Send:Jitter
# ...

# %%
## Extract results from "diff_floor.log" 
each_log_path = os.path.join(log_file_path, log_list[4])
df_diff_floor = pd.DataFrame(columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                        'Send:Pack', 'Send:Lost%', 'Send:Jitter'])

f = open(each_log_path, "r")
for each_line in f:
    line_split = each_line.split()
    if (len(line_split) == 13):
        df_each_line = pd.DataFrame([[line_split[0], line_split[3], line_split[6].replace('%)',''), line_split[7],
                                      line_split[8], line_split[11].replace('%)',''), line_split[12]]], 
                                    columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                               'Send:Pack', 'Send:Lost%', 'Send:Jitter'])
        df_diff_floor = pd.concat([df_diff_floor, df_each_line])
        
print("="*70)
print("Results at : ", log_list[4])
print("="*70)
print(df_diff_floor)
# Out:
# ...
# Results at :  diff_floor.log
# ...
#               Peer   Recv:Pack Recv:Lost% Recv:Jitter   Send:Pack Send:Lost%  \
# 0   10.127.204.227  0000000619       0.32      0.0000  0000000608       0.33
# 0    10.127.10.203  0000000255       0.00      0.0000  0000000249       0.40
# 0   10.127.204.227  0000000667       0.30      0.0000  0000000660       0.15
# 0    10.127.10.203  0000000304       0.00      0.0000  0000000300       0.33
# 0   10.127.204.227  0000000724       0.28      0.0000  0000000713       0.14
# ..             ...         ...        ...         ...         ...        ...
# 0    10.127.10.203  0000003292       0.15      0.0000  0000003262       0.52
# 0   10.127.204.227  0000003705       0.35      0.0000  0000003701       0.76
# 0    10.127.10.203  0000003347       0.15      0.0000  0000003315       0.51
# 0   10.127.204.227  0000003754       0.35      0.0000  0000003754       0.75
# 0    10.127.10.203  0000003396       0.15      0.0000  0000003368       0.50
#
# ...

# %%
## Extract results from "diff_place_sec_to_fountain.log" 
each_log_path = os.path.join(log_file_path, log_list[5])
df_fountain = pd.DataFrame(columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                      'Send:Pack', 'Send:Lost%', 'Send:Jitter'])

f = open(each_log_path, "r")
for each_line in f:
    line_split = each_line.split()
    if (len(line_split) == 13):
        df_each_line = pd.DataFrame([[line_split[0], line_split[3], line_split[6].replace('%)',''), line_split[7],
                                      line_split[8], line_split[11].replace('%)',''), line_split[12]]], 
                                    columns = ['Peer', 'Recv:Pack', 'Recv:Lost%', 'Recv:Jitter', 
                                               'Send:Pack', 'Send:Lost%', 'Send:Jitter'])
        df_fountain = pd.concat([df_fountain, df_each_line])
        
print("="*70)
print("Results at : ", log_list[5])
print("="*70)
print(df_fountain)
# Out:
# ...
# Results at :  diff_place_sec_to_fountain.log
# ...
#              Peer   Recv:Pack Recv:Lost% Recv:Jitter   Send:Pack Send:Lost%  \
# 0   10.127.10.203  0000000350       0.00      0.0000  0000000335       0.00
# 0  10.127.204.227  0000000578       0.00      0.0000  0000000644       3.57
# 0   10.127.10.203  0000000400       0.00      0.0000  0000000373       0.00
# 0  10.127.204.227  0000000606       0.00      0.0000  0000000696       3.30
# 0   10.127.10.203  0000000451       0.00      0.0000  0000000398       0.00
# 0  10.127.204.227  0000000661       0.00      0.0000  0000000748       3.07
# 0   10.127.10.203  0000000501       0.00      0.0000  0000000432       0.00
# 0  10.127.204.227  0000000685       0.00      0.0000  0000000801       2.87
# 0   10.127.10.203  0000000558       0.00      0.0000  0000000466       4.94
# 0  10.127.204.227  0000000720       0.00      0.0000  0000000852       3.76
# 0   10.127.10.203  0000000611       0.00      0.0000  0000000491       4.68
# ...

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.title("SEC to Fountain", fontsize = 20)

plt.plot(np.arange(30), df_fountain[0: :2]['Send:Jitter'].astype(float).values.tolist(), 
         'bo-', linewidth = '2', label='Peer::10.127.10.203')
plt.plot(np.arange(29), df_fountain[1: :2]['Send:Jitter'].astype(float).values.tolist(),
         'go-', linewidth = '2', label='Peer::10.127.204.227')
plt.xlabel("Time (Second)", fontsize = 20)
plt.ylabel("Send Jitter", fontsize = 20)

plt.yticks(np.linspace(min(df_fountain[1: :2]['Send:Jitter'].astype(float).values.tolist()), 
                       max(df_fountain[1: :2]['Send:Jitter'].astype(float).values.tolist()), 15))

plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.title("SEC to Bus Hub", fontsize = 20)

plt.plot(np.arange(61), df_bus_hub[1: :2]['Send:Jitter'].astype(float).values.tolist(),
         'bo-', linewidth = '2', label='Peer::10.127.10.203')
plt.plot(np.arange(61), df_bus_hub[0: :2]['Send:Jitter'].astype(float).values.tolist(), 
         'go-', linewidth = '2', label='Peer::10.127.204.227')
plt.xlabel("Time (Second)", fontsize = 20)
plt.ylabel("Send Jitter", fontsize = 20)

plt.yticks(np.linspace(min(df_bus_hub[0: :2]['Send:Jitter'].astype(float).values.tolist()), 
                       max(df_bus_hub[0: :2]['Send:Jitter'].astype(float).values.tolist()), 15))

plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.title("Within Same Floor at SEC", fontsize = 20)
plt.plot(np.arange(61), df_in_floor[0: :2]['Send:Jitter'].astype(float).values.tolist(), 
         'bo-', linewidth = '2', label='Peer::10.127.10.203')
plt.plot(np.arange(61), df_in_floor[1: :2]['Send:Jitter'].astype(float).values.tolist(), 
         'go-', linewidth = '2', label='Peer::10.127.204.227')
plt.xlabel("Time (Second)", fontsize = 20)
plt.ylabel("Send Jitter", fontsize = 20)

plt.yticks(np.linspace(min(df_in_floor[0: :2]['Send:Jitter'].astype(float).values.tolist()), 
                       max(df_in_floor[0: :2]['Send:Jitter'].astype(float).values.tolist()), 15))

plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.title("Within Lab at SEC", fontsize = 20)
plt.plot(np.arange(61), df_in_lab[0: :2]['Send:Jitter'].astype(float).values.tolist(), 
         'bo-', linewidth = '2', label='Peer::10.127.10.203')
plt.plot(np.arange(61), df_in_lab[1: :2]['Send:Jitter'].astype(float).values.tolist(), 
         'go-', linewidth = '2', label='Peer::10.127.204.227')
plt.xlabel("Time (Second)", fontsize = 20)
plt.ylabel("Send Jitter", fontsize = 20)
plt.yticks(np.linspace(min(df_in_lab[1: :2]['Send:Jitter'].astype(float).values.tolist()), 
                       max(df_in_lab[1: :2]['Send:Jitter'].astype(float).values.tolist()), 15))
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 10), dpi=80)
plt.title("Different Floors at SEC", fontsize = 20)
plt.plot(np.arange(61), df_diff_floor[1: :2]['Send:Jitter'].astype(float).values.tolist(), 
         'bo-', linewidth = '2', label='Peer::10.127.10.203')
plt.plot(np.arange(61), df_diff_floor[0: :2]['Send:Jitter'].astype(float).values.tolist(), 
         'go-', linewidth = '2', label='Peer::10.127.204.227')
plt.xlabel("Time (Second)", fontsize = 20)
plt.ylabel("Send Jitter", fontsize = 20)
plt.yticks(np.linspace(min(df_diff_floor[0: :2]['Send:Jitter'].astype(float).values.tolist()), 
                       max(df_diff_floor[0: :2]['Send:Jitter'].astype(float).values.tolist()), 15))
plt.legend()
plt.show()
